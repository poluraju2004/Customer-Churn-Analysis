# %% [markdown]
# # Customer Churn Analysis

# %% [markdown]
# # Import Libraries

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# # Load dataset

# %%
df = pd.read_csv("C:\\Users\\polur\\Desktop\\Customer Churn Analysis\\Dataset\\raw\\customer_churn.csv")
print(df)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # # Print first 5 rows

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # # Print Last 5 rows

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# # Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# # Data Set Data Types

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# # Columns

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=7043, step=1)

# %% [markdown]
# # Selecting  Data Rows and Columns

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df["customerID"]
# Out:
# 0       7590-VHVEG
# 1       5575-GNVDE
# 2       3668-QPYBK
# 3       7795-CFOCW
# 4       9237-HQITU
#            ...
# 7038    6840-RESVB
# 7039    2234-XADUH
# 7040    4801-JZAZL
# 7041    8361-LTMKD
# 7042    3186-AJIEK
# Name: customerID, Length: 7043, dtype: object

# %%
df[['gender','SeniorCitizen']]
# Out:
#       gender  SeniorCitizen
# 0     Female              0
# 1       Male              0
# 2       Male              0
# 3       Male              0
# 4     Female              0
# ...      ...            ...
# 7038    Male              0
# 7039  Female              0
# 7040  Female              0
# 7041    Male              1
# 7042    Male              0
#
# [7043 rows x 2 columns]

# %%
df.iloc(0)

# %%
df.loc(0)

# %%
df.loc[5,'MonthlyCharges']
# Out:
# np.float64(99.65)

# %%
df.iloc[0,5]
# Out:
# np.int64(1)

# %%
df['MonthlyCharges']
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
df[df['MonthlyCharges']>104.8]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# 38    5380-WJKOV    Male              0      No         No      34
# 57    5067-XJQFU    Male              1     Yes        Yes      66
# ...          ...     ...            ...     ...        ...     ...
# 6972  6664-FPDAC  Female              1      No         No      56
# 6987  5981-ZVXOT  Female              1      No         No      35
# 7002  9586-JGQKH  Female              0     Yes         No      64
# 7022  7203-OYKCT    Male              0      No         No      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 14            Yes            No     Fiber optic            Yes  ...
# ...

# %%
df.iloc[0:5,0:6]
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure
# 0  7590-VHVEG  Female              0     Yes         No       1
# 1  5575-GNVDE    Male              0      No         No      34
# 2  3668-QPYBK    Male              0      No         No       2
# 3  7795-CFOCW    Male              0      No         No      45
# 4  9237-HQITU  Female              0      No         No       2

# %% [markdown]
# # Data Cleaning

# %%
df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Percentage of missing values:

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# customerID          0.0
# gender              0.0
# SeniorCitizen       0.0
# Partner             0.0
# Dependents          0.0
# tenure              0.0
# PhoneService        0.0
# MultipleLines       0.0
# InternetService     0.0
# OnlineSecurity      0.0
# OnlineBackup        0.0
# DeviceProtection    0.0
# TechSupport         0.0
# StreamingTV         0.0
# StreamingMovies     0.0
# Contract            0.0
# PaperlessBilling    0.0
# PaymentMethod       0.0
# MonthlyCharges      0.0
# TotalCharges        0.0
# Churn               0.0
# dtype: float64

# %%
df.notnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0           True    True           True     True        True    True
# 1           True    True           True     True        True    True
# 2           True    True           True     True        True    True
# 3           True    True           True     True        True    True
# 4           True    True           True     True        True    True
# ...          ...     ...            ...      ...         ...     ...
# 7038        True    True           True     True        True    True
# 7039        True    True           True     True        True    True
# 7040        True    True           True     True        True    True
# 7041        True    True           True     True        True    True
# 7042        True    True           True     True        True    True
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.fillna(0)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.fillna(1)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.drop_duplicates()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.drop_duplicates().sum()
# Out:
# customerID          7590-VHVEG5575-GNVDE3668-QPYBK7795-CFOCW9237-H...
# gender              FemaleMaleMaleMaleFemaleFemaleMaleFemaleFemale...
# SeniorCitizen                                                    1142
# Partner             YesNoNoNoNoNoNoNoYesNoYesNoYesNoNoYesNoNoYesNo...
# Dependents          NoNoNoNoNoNoYesNoNoYesYesNoNoNoNoYesNoYesYesNo...
# tenure                                                         227990
# PhoneService        NoYesYesNoYesYesYesNoYesYesYesYesYesYesYesYesY...
# MultipleLines       No phone serviceNoNoNo phone serviceNoYesYesNo...
# InternetService     DSLDSLDSLDSLFiber opticFiber opticFiber opticD...
# OnlineSecurity      NoYesYesYesNoNoNoYesNoYesYesNo internet servic...
# OnlineBackup        YesNoYesNoNoNoYesNoNoYesNoNo internet serviceN...
# DeviceProtection    NoYesNoYesNoYesNoNoYesNoNoNo internet serviceY...
# TechSupport         NoNoNoYesNoNoNoNoYesNoNoNo internet serviceNoN...
# ...

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['Churn'].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['customerID'].unique()
# Out:
# array(['7590-VHVEG', '5575-GNVDE', '3668-QPYBK', ..., '4801-JZAZL',
#        '8361-LTMKD', '3186-AJIEK'], shape=(7043,), dtype=object)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df['TotalCharges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: TotalCharges, Length: 7043, dtype: object

# %%
df['TotalCharges'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Rename

# %%
df = df.rename(columns = {'TotalCharges':'Total_Charges'})

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'Total_Charges', 'Churn'],
#       dtype='object')

# %%
df['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3        No
# 4       Yes
#        ...
# 7038     No
# 7039     No
# 7040     No
# 7041    Yes
# 7042     No
# Name: Churn, Length: 7043, dtype: object

# %% [markdown]
# # Replace

# %%
df['Churn'] = df['Churn'].replace({'Yes':1,"No":0}).astype(int)
# Out:
# C:\Users\polur\AppData\Local\Temp\ipykernel_14660\3140524533.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Churn'] = df['Churn'].replace({'Yes':1,"No":0}).astype(int)

# %%
df["Churn"].value_counts()
# Out:
# Churn
# 0    5174
# 1    1869
# Name: count, dtype: int64

# %%
df['gender']
# Out:
# 0       Female
# 1         Male
# 2         Male
# 3         Male
# 4       Female
#          ...
# 7038      Male
# 7039    Female
# 7040    Female
# 7041      Male
# 7042      Male
# Name: gender, Length: 7043, dtype: object

# %% [markdown]
# # Sort Filter Data

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'Total_Charges', 'Churn'],
#       dtype='object')

# %%
df.sort_values("customerID")
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2307  0002-ORFBO  Female              0     Yes        Yes       9
# 3488  0003-MKNFE    Male              0      No         No       9
# 3845  0004-TLHLJ    Male              0      No         No       4
# 5931  0011-IGKFF    Male              1     Yes         No      13
# 5569  0013-EXCHZ  Female              1     Yes         No       3
# ...          ...     ...            ...     ...        ...     ...
# 3607  9987-LUTYD  Female              0      No         No      13
# 2875  9992-RRAMN    Male              0     Yes         No      22
# 1260  9992-UJOEL    Male              0      No         No       2
# 1996  9993-LHIEB    Male              0     Yes        Yes      67
# 1634  9995-HOTOH    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 2307          Yes                No             DSL             No  ...
# ...

# %%
df.sort_values("customerID",ascending = False)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1634  9995-HOTOH    Male              0     Yes        Yes      63
# 1996  9993-LHIEB    Male              0     Yes        Yes      67
# 1260  9992-UJOEL    Male              0      No         No       2
# 2875  9992-RRAMN    Male              0     Yes         No      22
# 3607  9987-LUTYD  Female              0      No         No      13
# ...          ...     ...            ...     ...        ...     ...
# 5569  0013-EXCHZ  Female              1     Yes         No       3
# 5931  0011-IGKFF    Male              1     Yes         No      13
# 3845  0004-TLHLJ    Male              0      No         No       4
# 3488  0003-MKNFE    Male              0      No         No       9
# 2307  0002-ORFBO  Female              0     Yes        Yes       9
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1634           No  No phone service             DSL            Yes  ...
# ...

# %%
df.sort_values(['customerID',"gender"],ascending = True)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2307  0002-ORFBO  Female              0     Yes        Yes       9
# 3488  0003-MKNFE    Male              0      No         No       9
# 3845  0004-TLHLJ    Male              0      No         No       4
# 5931  0011-IGKFF    Male              1     Yes         No      13
# 5569  0013-EXCHZ  Female              1     Yes         No       3
# ...          ...     ...            ...     ...        ...     ...
# 3607  9987-LUTYD  Female              0      No         No      13
# 2875  9992-RRAMN    Male              0     Yes         No      22
# 1260  9992-UJOEL    Male              0      No         No       2
# 1996  9993-LHIEB    Male              0     Yes        Yes      67
# 1634  9995-HOTOH    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 2307          Yes                No             DSL             No  ...
# ...

# %%
df.sort_values(['customerID',"gender"],ascending = False)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1634  9995-HOTOH    Male              0     Yes        Yes      63
# 1996  9993-LHIEB    Male              0     Yes        Yes      67
# 1260  9992-UJOEL    Male              0      No         No       2
# 2875  9992-RRAMN    Male              0     Yes         No      22
# 3607  9987-LUTYD  Female              0      No         No      13
# ...          ...     ...            ...     ...        ...     ...
# 5569  0013-EXCHZ  Female              1     Yes         No       3
# 5931  0011-IGKFF    Male              1     Yes         No      13
# 3845  0004-TLHLJ    Male              0      No         No       4
# 3488  0003-MKNFE    Male              0      No         No       9
# 2307  0002-ORFBO  Female              0     Yes        Yes       9
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 1634           No  No phone service             DSL            Yes  ...
# ...

# %%
df.sort_values(['customerID',"gender"],ascending =[True,False])
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 2307  0002-ORFBO  Female              0     Yes        Yes       9
# 3488  0003-MKNFE    Male              0      No         No       9
# 3845  0004-TLHLJ    Male              0      No         No       4
# 5931  0011-IGKFF    Male              1     Yes         No      13
# 5569  0013-EXCHZ  Female              1     Yes         No       3
# ...          ...     ...            ...     ...        ...     ...
# 3607  9987-LUTYD  Female              0      No         No      13
# 2875  9992-RRAMN    Male              0     Yes         No      22
# 1260  9992-UJOEL    Male              0      No         No       2
# 1996  9993-LHIEB    Male              0     Yes        Yes      67
# 1634  9995-HOTOH    Male              0     Yes        Yes      63
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 2307          Yes                No             DSL             No  ...
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'Total_Charges', 'Churn'],
#       dtype='object')

# %%
df['customerID']
# Out:
# 0       7590-VHVEG
# 1       5575-GNVDE
# 2       3668-QPYBK
# 3       7795-CFOCW
# 4       9237-HQITU
#            ...
# 7038    6840-RESVB
# 7039    2234-XADUH
# 7040    4801-JZAZL
# 7041    8361-LTMKD
# 7042    3186-AJIEK
# Name: customerID, Length: 7043, dtype: object

# %%
df['MonthlyCharges']
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
df.query('MonthlyCharges > 104.8')
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 17    9959-WOFKT    Male              0      No        Yes      71
# 38    5380-WJKOV    Male              0      No         No      34
# 57    5067-XJQFU    Male              1     Yes        Yes      66
# ...          ...     ...            ...     ...        ...     ...
# 6972  6664-FPDAC  Female              1      No         No      56
# 6987  5981-ZVXOT  Female              1      No         No      35
# 7002  9586-JGQKH  Female              0     Yes         No      64
# 7022  7203-OYKCT    Male              0      No         No      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 14            Yes            No     Fiber optic            Yes  ...
# ...

# %%
df.sample(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 852   8713-IGZSO    Male              0      No         No       2
# 1482  9290-SHCMB  Female              1      No         No      13
# 94    9848-JQJTX    Male              0      No         No      72
# 4292  2091-RFFBA  Female              1      No         No      31
# 1176  3992-YWPKO  Female              0      No         No       6
# 416   4686-GEFRM    Male              0     Yes         No      70
# 6692  8591-NXRCV  Female              0      No         No      41
# 100   6380-ARCEH    Male              0      No         No       1
# 3288  1843-TLSGD  Female              0     Yes        Yes      13
# 6672  2346-CZYIL    Male              0      No         No      27
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 852           Yes           Yes              No  No internet service  ...
# 1482          Yes            No     Fiber optic                   No  ...
# ...

# %%
df['MonthlyCharges']
# Out:
# 0        29.85
# 1        56.95
# 2        53.85
# 3        42.30
# 4        70.70
#          ...
# 7038     84.80
# 7039    103.20
# 7040     29.60
# 7041     74.40
# 7042    105.65
# Name: MonthlyCharges, Length: 7043, dtype: float64

# %%
df.nlargest(3,"MonthlyCharges")
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4586  7569-NMZYQ  Female              0     Yes        Yes      72
# 2115  8984-HPEMB  Female              0      No         No      71
# 3894  5989-AXPUC  Female              0     Yes         No      68
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 4586          Yes           Yes     Fiber optic            Yes  ...
# 2115          Yes           Yes     Fiber optic            Yes  ...
# 3894          Yes           Yes     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 4586              Yes         Yes         Yes             Yes  Two year
# 2115              Yes         Yes         Yes             Yes  Two year
# 3894              Yes         Yes         Yes             Yes  Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  \
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'Total_Charges', 'Churn'],
#       dtype='object')

# %%
df.nsmallest(5, "MonthlyCharges")
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 3719  6823-SIDFQ    Male              0      No         No      28
# 1529  9764-REAFF  Female              0     Yes         No      59
# 6652  0827-ITJPH    Male              0      No         No      36
# 1156  0621-CXBKL  Female              0      No         No      53
# 6906  9945-PSVIP  Female              0     Yes        Yes      25
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  ...  \
# 3719          Yes            No              No  No internet service  ...
# 1529          Yes            No              No  No internet service  ...
# 6652          Yes            No              No  No internet service  ...
# 1156          Yes            No              No  No internet service  ...
# 6906          Yes            No              No  No internet service  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.filter(items=["customerID","gender","Churn"])
# Out:
#       customerID  gender  Churn
# 0     7590-VHVEG  Female      0
# 1     5575-GNVDE    Male      0
# 2     3668-QPYBK    Male      1
# 3     7795-CFOCW    Male      0
# 4     9237-HQITU  Female      1
# ...          ...     ...    ...
# 7038  6840-RESVB    Male      0
# 7039  2234-XADUH  Female      0
# 7040  4801-JZAZL  Female      0
# 7041  8361-LTMKD    Male      1
# 7042  3186-AJIEK    Male      0
#
# [7043 rows x 3 columns]

# %% [markdown]
# # Group data

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'Total_Charges', 'Churn'],
#       dtype='object')

# %%
df.groupby("gender")

# %%
df.groupby("gender").sum()
# Out:
#                                                customerID  SeniorCitizen  \
# gender
# Female  7590-VHVEG9237-HQITU9305-CDSKC6713-OKOMC7892-P...            568
# Male    5575-GNVDE3668-QPYBK7795-CFOCW1452-KIOVK6388-T...            574
#
#                                                   Partner  \
# gender
# Female  YesNoNoNoYesYesNoYesNoYesNoNoYesYesYesNoNoYesY...
# Male    NoNoNoNoNoYesNoYesNoNoNoNoYesNoYesYesYesYesYes...
#
#                                                Dependents  tenure  \
# gender
# Female  NoNoNoNoNoYesNoYesNoNoNoYesNoYesYesNoNoYesYesN...  112469
# Male    NoNoNoYesYesYesNoNoNoNoYesNoNoNoYesYesYesNoNoN...  115521
#
#                                              PhoneService  \
# gender
# Female  NoYesYesNoYesYesYesYesYesYesYesYesYesYesYesYes...
# Male    YesYesNoYesYesYesYesYesYesYesYesNoYesYesYesYes...
#
#                                             MultipleLines  \
# gender
# Female  No phone serviceNoYesNo phone serviceYesYesNoN...
# ...

# %%
df.groupby("SeniorCitizen").sum()
# Out:
#                                                       customerID  \
# SeniorCitizen
# 0              7590-VHVEG5575-GNVDE3668-QPYBK7795-CFOCW9237-H...
# 1              8779-QRDMV3841-NFECX4929-XIHVW3413-BMNZE8012-S...
#
#                                                           gender  \
# SeniorCitizen
# 0              FemaleMaleMaleMaleFemaleFemaleMaleFemaleFemale...
# 1              MaleFemaleMaleMaleFemaleFemaleFemaleFemaleMale...
#
#                                                          Partner  \
# SeniorCitizen
# 0              YesNoNoNoNoNoNoNoYesNoYesNoYesNoNoYesNoNoYesNo...
# 1              NoYesYesNoNoYesYesYesNoYesYesNoNoNoYesYesYesNo...
#
#                                                       Dependents  tenure  \
# SeniorCitizen
# 0              NoNoNoNoNoNoYesNoNoYesYesNoNoNoNoYesNoYesYesNo...  189966
# 1              NoNoNoNoNoNoNoYesNoYesYesNoNoNoNoNoNoNoNoNoYes...   38024
#
#                                                     PhoneService  \
# SeniorCitizen
# ...

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.groupby("SeniorCitizen").min()
# Out:
#                customerID  gender Partner Dependents  tenure PhoneService  \
# SeniorCitizen
# 0              0002-ORFBO  Female      No         No       0           No
# 1              0011-IGKFF  Female      No         No       1           No
#
#               MultipleLines InternetService OnlineSecurity OnlineBackup  \
# SeniorCitizen
# 0                        No             DSL             No           No
# 1                        No             DSL             No           No
#
#               DeviceProtection TechSupport StreamingTV StreamingMovies  \
# SeniorCitizen
# 0                           No          No          No              No
# 1                           No          No          No              No
#
#                      Contract PaperlessBilling              PaymentMethod  \
# SeniorCitizen
# 0              Month-to-month               No  Bank transfer (automatic)
# 1              Month-to-month               No  Bank transfer (automatic)
#
# ...

# %%
df.groupby("gender")["Total_Charges"].max()
# Out:
# gender
# Female    999.9
# Male      999.8
# Name: Total_Charges, dtype: object

# %%
df.groupby("customerID")["Total_Charges"].max()
# Out:
# customerID
# 0002-ORFBO      593.3
# 0003-MKNFE      542.4
# 0004-TLHLJ     280.85
# 0011-IGKFF    1237.85
# 0013-EXCHZ      267.4
#                ...
# 9987-LUTYD      742.9
# 9992-RRAMN     1873.7
# 9992-UJOEL      92.75
# 9993-LHIEB    4627.65
# 9995-HOTOH     3707.6
# Name: Total_Charges, Length: 7043, dtype: object

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'Total_Charges', 'Churn'],
#       dtype='object')

# %%
pd.pivot_table(df,index="Contract",values="MonthlyCharges",aggfunc="mean")
# Out:
#                 MonthlyCharges
# Contract
# Month-to-month       66.398490
# One year             65.048608
# Two year             60.770413

# %% [markdown]
# # Statistical Operations

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges        Churn
# count    7043.000000  7043.000000     7043.000000  7043.000000
# mean        0.162147    32.371149       64.761692     0.265370
# std         0.368612    24.559481       30.090047     0.441561
# min         0.000000     0.000000       18.250000     0.000000
# 25%         0.000000     9.000000       35.500000     0.000000
# 50%         0.000000    29.000000       70.350000     0.000000
# 75%         0.000000    55.000000       89.850000     1.000000
# max         1.000000    72.000000      118.750000     1.000000

# %%
df['MonthlyCharges'].max()
# Out:
# np.float64(118.75)

# %%
df['SeniorCitizen'].count()
# Out:
# np.int64(7043)

# %%
df[['SeniorCitizen','MonthlyCharges']].min()
# Out:
# SeniorCitizen      0.00
# MonthlyCharges    18.25
# dtype: float64

# %%
df['MonthlyCharges'].var()
# Out:
# np.float64(905.4109343405098)

# %%
df.to_csv("C:/Users/polur/Desktop/Customer Churn Analysis/Dataset/Cleaned_Data/customer_churn_Cleaned_dataset.csv")
df.shape
# Out:
# (7043, 21)
